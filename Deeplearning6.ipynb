# %%
# Importing required packages
# tesnsorflow, numpy, pandas
# cv2 for drawing rectangle on images
# tdqm for showing progress bar
# shutil for copying images

# %%
import os, time, random
import numpy as np
import pandas as pd
import cv2, torch
from tqdm.auto import tqdm
import shutil as sh

# %%
from IPython.display import Image, clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 # clone repo
# !pip install -U pycocotools
# !pip install -qr yolov5/requirements.txt # install dependencies
# !cp yolov5/requirements.txt ./
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15701, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 15701 (delta 7), reused 18 (delta 4), pack-reused 15672
# Receiving objects: 100% (15701/15701), 14.43 MiB | 19.44 MiB/s, done.
# Resolving deltas: 100% (10753/10753), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 20.7 MB/s eta 0:00:00

# %%
img_h, img_w, num_channels = (380, 676, 3)
df = pd.read_csv('/content/train_solution_bounding_boxes (1).csv')
df.rename(columns={'image':'image_id'}, inplace=True)
df['image_id'] = df['image_id'].apply(lambda x: x.split('.')[0])
df['x_center'] = (df['xmin'] + df['xmax'])/2
df['y_center'] = (df['ymin'] + df['ymax'])/2
df['w'] = df['xmax'] - df['xmin']
df['h'] = df['ymax'] - df['ymin']
df['classes'] = 0
df['x_center'] = df['x_center']/img_w
df['w'] = df['w']/img_w
df['y_center'] = df['y_center']/img_h
df['h'] = df['h']/img_h
df.head()
# Out:
#       image_id        xmin        ymin        xmax        ymax  x_center  \
# 0   vid_4_1000  281.259045  187.035071  327.727931  223.225547  0.450434
# 1  vid_4_10000   15.163531  187.035071  120.329957  236.430180  0.100217
# 2  vid_4_10040  239.192475  176.764801  361.968162  236.430180  0.444645
# 3  vid_4_10020  496.483358  172.363256  630.020260  231.539575  0.833213
# 4  vid_4_10060   16.630970  186.546010  132.558611  238.386422  0.110347
#
#    y_center         w         h  classes
# 0  0.539817  0.068741  0.095238        0
# 1  0.557191  0.155572  0.129987        0
# 2  0.543678  0.181621  0.157014        0
# 3  0.531451  0.197540  0.155727        0
# 4  0.559122  0.171491  0.136422        0

# %%
index = list(set(df.image_id))
image = random.choice(index)
print("Image ID: %s"%(image))
img = cv2.imread(f'/content/drive/MyDrive/data/training_images/{image}.jpg')
img.shape
# Out:
# Image ID: vid_4_11260
# (380, 676, 3)

# %%
image = random.choice(index)
Image(filename=f'/content/drive/MyDrive/data/testing_images/{image}.jpg',width=600)

# %%
source = 'training_images'
if True:
    for fold in [0]:
        val_index = index[len(index)*fold//5:len(index)*(fold+1)//5]
        for name,mini in tqdm(df.groupby('image_id')):
            if name in val_index:
                path2save = 'val2017/'
            else:
                path2save = 'train2017/'
            if not os.path.exists('/tmp/convertor/fold{}/labels/'.format(fold)+path2save):
                os.makedirs('/tmp/convertor/fold{}/labels/'.format(fold)+path2save)
            with open('/tmp/convertor/fold{}/labels/'.format(fold)+path2save+name+".txt", 'w+') as f:
                row = mini[['classes','x_center','y_center','w','h']].astype(float).values
                row = row.astype(str)
                for j in range(len(row)):
                    text = ' '.join(row[j])
                    f.write(text)
                    f.write("\n")
            if not os.path.exists('/tmp/convertor/fold{}/images/{}'.format(fold,path2save)):
                os.makedirs('/tmp/convertor/fold{}/images/{}'.format(fold,path2save))
            sh.copy("/content/drive/MyDrive/data/{}/{}.jpg".format(source,name),'/tmp/convertor/fold{}/images/{}/{}.jpg'.format(fold,path2save,name))
# Out:
#   0%|          | 0/355 [00:00<?, ?it/s]

# %% [markdown]
# **Prediction**

# %%
# !python yolov5/detect.py --weights yolov5/yolov5s.pt --img 676 --conf 0.4 --source /content/drive/MyDrive/data/testing_images
# Out:
# detect: weights=['yolov5/yolov5s.pt'], source=/content/drive/MyDrive/data/testing_images, data=yolov5/data/coco128.yaml, imgsz=[676, 676], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-171-g6e04b94 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5/yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 44.1MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ --img-size [676, 676] must be multiple of max stride 32, updating to [704, 704]
# image 1/175 /content/drive/MyDrive/data/testing_images/vid_5_25100.jpg: 416x704 (no detections), 303.5ms
# image 2/175 /content/drive/MyDrive/data/testing_images/vid_5_25120.jpg: 416x704 (no detections), 362.4ms
# image 3/175 /content/drive/MyDrive/data/testing_images/vid_5_25140.jpg: 416x704 (no detections), 253.3ms
# image 4/175 /content/drive/MyDrive/data/testing_images/vid_5_25160.jpg: 416x704 (no detections), 275.9ms
# image 5/175 /content/drive/MyDrive/data/testing_images/vid_5_25180.jpg: 416x704 (no detections), 229.5ms
# image 6/175 /content/drive/MyDrive/data/testing_images/vid_5_25200.jpg: 416x704 (no detections), 222.6ms
# image 7/175 /content/drive/MyDrive/data/testing_images/vid_5_25220.jpg: 416x704 (no detections), 253.6ms
# image 8/175 /content/drive/MyDrive/data/testing_images/vid_5_25240.jpg: 416x704 (no detections), 243.6ms
# image 9/175 /content/drive/MyDrive/data/testing_images/vid_5_25260.jpg: 416x704 (no detections), 233.3ms
# image 10/175 /content/drive/MyDrive/data/testing_images/vid_5_26320.jpg: 416x704 (no detections), 236.4ms
# image 11/175 /content/drive/MyDrive/data/testing_images/vid_5_26400.jpg: 416x704 (no detections), 223.1ms
# image 12/175 /content/drive/MyDrive/data/testing_images/vid_5_26420.jpg: 416x704 (no detections), 293.8ms
# image 13/175 /content/drive/MyDrive/data/testing_images/vid_5_26560.jpg: 416x704 1 car, 310.3ms
# image 14/175 /content/drive/MyDrive/data/testing_images/vid_5_26580.jpg: 416x704 1 car, 359.9ms
# image 15/175 /content/drive/MyDrive/data/testing_images/vid_5_26600.jpg: 416x704 2 cars, 366.4ms
# image 16/175 /content/drive/MyDrive/data/testing_images/vid_5_26620.jpg: 416x704 1 car, 346.8ms
# image 17/175 /content/drive/MyDrive/data/testing_images/vid_5_26640.jpg: 416x704 3 cars, 341.9ms
# image 18/175 /content/drive/MyDrive/data/testing_images/vid_5_26660.jpg: 416x704 1 car, 332.2ms
# image 19/175 /content/drive/MyDrive/data/testing_images/vid_5_26680.jpg: 416x704 3 cars, 1 truck, 346.1ms
# image 74/175 /content/drive/MyDrive/data/testing_images/vid_5_28040.jpg: 416x704 (no detections), 219.8ms
# image 75/175 /content/drive/MyDrive/data/testing_images/vid_5_28060.jpg: 416x704 (no detections), 224.5ms
# image 76/175 /content/drive/MyDrive/data/testing_images/vid_5_28080.jpg: 416x704 (no detections), 240.0ms
# image 77/175 /content/drive/MyDrive/data/testing_images/vid_5_28180.jpg: 416x704 (no detections), 237.3ms
# image 78/175 /content/drive/MyDrive/data/testing_images/vid_5_28260.jpg: 416x704 1 car, 228.5ms
# image 79/175 /content/drive/MyDrive/data/testing_images/vid_5_28320.jpg: 416x704 (no detections), 234.4ms
# image 80/175 /content/drive/MyDrive/data/testing_images/vid_5_28340.jpg: 416x704 (no detections), 224.6ms
# image 81/175 /content/drive/MyDrive/data/testing_images/vid_5_28360.jpg: 416x704 (no detections), 235.7ms
# image 82/175 /content/drive/MyDrive/data/testing_images/vid_5_28380.jpg: 416x704 1 car, 238.9ms
# image 83/175 /content/drive/MyDrive/data/testing_images/vid_5_28420.jpg: 416x704 1 car, 227.1ms
# image 84/175 /content/drive/MyDrive/data/testing_images/vid_5_28440.jpg: 416x704 1 car, 1 truck, 232.2ms
# image 85/175 /content/drive/MyDrive/data/testing_images/vid_5_28460.jpg: 416x704 (no detections), 229.0ms
# image 86/175 /content/drive/MyDrive/data/testing_images/vid_5_28480.jpg: 416x704 (no detections), 229.8ms
# image 87/175 /content/drive/MyDrive/data/testing_images/vid_5_28500.jpg: 416x704 1 car, 225.5ms
# image 88/175 /content/drive/MyDrive/data/testing_images/vid_5_28520.jpg: 416x704 1 car, 1 truck, 222.6ms
# image 89/175 /content/drive/MyDrive/data/testing_images/vid_5_28540.jpg: 416x704 1 truck, 233.9ms
# image 90/175 /content/drive/MyDrive/data/testing_images/vid_5_28560.jpg: 416x704 (no detections), 223.7ms
# image 91/175 /content/drive/MyDrive/data/testing_images/vid_5_28580.jpg: 416x704 (no detections), 231.6ms
# image 92/175 /content/drive/MyDrive/data/testing_images/vid_5_28600.jpg: 416x704 (no detections), 248.6ms
# image 93/175 /content/drive/MyDrive/data/testing_images/vid_5_28620.jpg: 416x704 (no detections), 245.5ms
# image 94/175 /content/drive/MyDrive/data/testing_images/vid_5_28640.jpg: 416x704 (no detections), 237.4ms
# image 95/175 /content/drive/MyDrive/data/testing_images/vid_5_28660.jpg: 416x704 (no detections), 242.8ms
# image 96/175 /content/drive/MyDrive/data/testing_images/vid_5_28680.jpg: 416x704 (no detections), 232.9ms
# image 97/175 /content/drive/MyDrive/data/testing_images/vid_5_28700.jpg: 416x704 (no detections), 232.3ms
# image 98/175 /content/drive/MyDrive/data/testing_images/vid_5_29000.jpg: 416x704 2 cars, 233.2ms
# image 99/175 /content/drive/MyDrive/data/testing_images/vid_5_29020.jpg: 416x704 1 car, 234.6ms
# image 100/175 /content/drive/MyDrive/data/testing_images/vid_5_29040.jpg: 416x704 1 car, 226.9ms
# image 101/175 /content/drive/MyDrive/data/testing_images/vid_5_29060.jpg: 416x704 (no detections), 228.1ms
# image 102/175 /content/drive/MyDrive/data/testing_images/vid_5_29080.jpg: 416x704 (no detections), 256.6ms
# image 103/175 /content/drive/MyDrive/data/testing_images/vid_5_29100.jpg: 416x704 (no detections), 239.3ms
# image 104/175 /content/drive/MyDrive/data/testing_images/vid_5_29400.jpg: 416x704 1 car, 221.3ms
# image 105/175 /content/drive/MyDrive/data/testing_images/vid_5_29420.jpg: 416x704 2 cars, 242.9ms
# image 106/175 /content/drive/MyDrive/data/testing_images/vid_5_29440.jpg: 416x704 2 cars, 231.2ms
# image 107/175 /content/drive/MyDrive/data/testing_images/vid_5_29460.jpg: 416x704 1 car, 230.6ms
# image 108/175 /content/drive/MyDrive/data/testing_images/vid_5_29480.jpg: 416x704 1 car, 221.9ms
# image 109/175 /content/drive/MyDrive/data/testing_images/vid_5_29500.jpg: 416x704 (no detections), 234.8ms
# image 110/175 /content/drive/MyDrive/data/testing_images/vid_5_29520.jpg: 416x704 (no detections), 231.4ms
# image 111/175 /content/drive/MyDrive/data/testing_images/vid_5_29540.jpg: 416x704 2 cars, 246.7ms
# image 112/175 /content/drive/MyDrive/data/testing_images/vid_5_29560.jpg: 416x704 1 car, 263.6ms
# image 113/175 /content/drive/MyDrive/data/testing_images/vid_5_29580.jpg: 416x704 1 car, 356.9ms
# image 114/175 /content/drive/MyDrive/data/testing_images/vid_5_29600.jpg: 416x704 (no detections), 355.8ms
# image 115/175 /content/drive/MyDrive/data/testing_images/vid_5_29620.jpg: 416x704 (no detections), 374.2ms
# image 116/175 /content/drive/MyDrive/data/testing_images/vid_5_29640.jpg: 416x704 (no detections), 365.5ms
# image 117/175 /content/drive/MyDrive/data/testing_images/vid_5_29720.jpg: 416x704 (no detections), 356.6ms
# image 118/175 /content/drive/MyDrive/data/testing_images/vid_5_29740.jpg: 416x704 (no detections), 351.8ms
# image 119/175 /content/drive/MyDrive/data/testing_images/vid_5_29760.jpg: 416x704 1 car, 350.7ms
# image 120/175 /content/drive/MyDrive/data/testing_images/vid_5_29820.jpg: 416x704 1 car, 321.3ms
# image 121/175 /content/drive/MyDrive/data/testing_images/vid_5_29840.jpg: 416x704 1 car, 1 truck, 294.8ms
# image 122/175 /content/drive/MyDrive/data/testing_images/vid_5_29860.jpg: 416x704 (no detections), 236.3ms
# image 123/175 /content/drive/MyDrive/data/testing_images/vid_5_29880.jpg: 416x704 (no detections), 223.8ms
# image 124/175 /content/drive/MyDrive/data/testing_images/vid_5_29900.jpg: 416x704 (no detections), 236.6ms
# image 125/175 /content/drive/MyDrive/data/testing_images/vid_5_29980.jpg: 416x704 1 person, 232.2ms
# image 126/175 /content/drive/MyDrive/data/testing_images/vid_5_30000.jpg: 416x704 (no detections), 234.2ms
# image 127/175 /content/drive/MyDrive/data/testing_images/vid_5_30020.jpg: 416x704 (no detections), 233.5ms
# image 128/175 /content/drive/MyDrive/data/testing_images/vid_5_30040.jpg: 416x704 (no detections), 227.8ms
# image 129/175 /content/drive/MyDrive/data/testing_images/vid_5_30120.jpg: 416x704 (no detections), 234.5ms
# image 130/175 /content/drive/MyDrive/data/testing_images/vid_5_30140.jpg: 416x704 (no detections), 228.5ms
# image 131/175 /content/drive/MyDrive/data/testing_images/vid_5_30160.jpg: 416x704 (no detections), 239.3ms
# image 132/175 /content/drive/MyDrive/data/testing_images/vid_5_30180.jpg: 416x704 (no detections), 236.0ms
# image 133/175 /content/drive/MyDrive/data/testing_images/vid_5_30640.jpg: 416x704 1 car, 237.0ms
# image 134/175 /content/drive/MyDrive/data/testing_images/vid_5_30660.jpg: 416x704 (no detections), 230.4ms
# image 135/175 /content/drive/MyDrive/data/testing_images/vid_5_30680.jpg: 416x704 (no detections), 246.1ms
# image 136/175 /content/drive/MyDrive/data/testing_images/vid_5_30700.jpg: 416x704 (no detections), 237.1ms
# image 137/175 /content/drive/MyDrive/data/testing_images/vid_5_30720.jpg: 416x704 (no detections), 236.7ms
# image 138/175 /content/drive/MyDrive/data/testing_images/vid_5_30740.jpg: 416x704 1 car, 1 truck, 228.3ms
# image 139/175 /content/drive/MyDrive/data/testing_images/vid_5_30760.jpg: 416x704 1 car, 3 traffic lights, 267.4ms
# image 140/175 /content/drive/MyDrive/data/testing_images/vid_5_30820.jpg: 416x704 2 cars, 6 traffic lights, 232.5ms
# image 141/175 /content/drive/MyDrive/data/testing_images/vid_5_30840.jpg: 416x704 2 cars, 5 traffic lights, 264.8ms
# image 142/175 /content/drive/MyDrive/data/testing_images/vid_5_30860.jpg: 416x704 3 cars, 3 traffic lights, 352.7ms
# image 143/175 /content/drive/MyDrive/data/testing_images/vid_5_30920.jpg: 416x704 2 cars, 2 traffic lights, 359.4ms
# image 144/175 /content/drive/MyDrive/data/testing_images/vid_5_30940.jpg: 416x704 2 cars, 2 traffic lights, 355.7ms
# image 145/175 /content/drive/MyDrive/data/testing_images/vid_5_31020.jpg: 416x704 2 cars, 376.6ms
# image 146/175 /content/drive/MyDrive/data/testing_images/vid_5_31040.jpg: 416x704 3 cars, 353.1ms
# image 147/175 /content/drive/MyDrive/data/testing_images/vid_5_31060.jpg: 416x704 1 car, 357.8ms
# image 148/175 /content/drive/MyDrive/data/testing_images/vid_5_31080.jpg: 416x704 2 cars, 363.0ms
# image 149/175 /content/drive/MyDrive/data/testing_images/vid_5_31100.jpg: 416x704 1 car, 335.0ms
# image 150/175 /content/drive/MyDrive/data/testing_images/vid_5_31120.jpg: 416x704 2 cars, 258.7ms
# image 151/175 /content/drive/MyDrive/data/testing_images/vid_5_31140.jpg: 416x704 1 car, 225.0ms
# image 152/175 /content/drive/MyDrive/data/testing_images/vid_5_31160.jpg: 416x704 1 car, 244.4ms
# image 153/175 /content/drive/MyDrive/data/testing_images/vid_5_31180.jpg: 416x704 (no detections), 228.1ms
# image 154/175 /content/drive/MyDrive/data/testing_images/vid_5_31200.jpg: 416x704 (no detections), 229.9ms
# image 155/175 /content/drive/MyDrive/data/testing_images/vid_5_31260.jpg: 416x704 (no detections), 231.5ms
# image 156/175 /content/drive/MyDrive/data/testing_images/vid_5_31280.jpg: 416x704 (no detections), 238.6ms
# image 157/175 /content/drive/MyDrive/data/testing_images/vid_5_31300.jpg: 416x704 (no detections), 260.0ms
# image 158/175 /content/drive/MyDrive/data/testing_images/vid_5_31360.jpg: 416x704 (no detections), 358.1ms
# image 159/175 /content/drive/MyDrive/data/testing_images/vid_5_31380.jpg: 416x704 (no detections), 369.9ms
# image 160/175 /content/drive/MyDrive/data/testing_images/vid_5_31400.jpg: 416x704 (no detections), 338.2ms
# image 161/175 /content/drive/MyDrive/data/testing_images/vid_5_31420.jpg: 416x704 (no detections), 353.8ms
# image 162/175 /content/drive/MyDrive/data/testing_images/vid_5_31480.jpg: 416x704 (no detections), 342.1ms
# image 163/175 /content/drive/MyDrive/data/testing_images/vid_5_31500.jpg: 416x704 (no detections), 334.9ms
# image 164/175 /content/drive/MyDrive/data/testing_images/vid_5_31520.jpg: 416x704 (no detections), 345.8ms
# image 165/175 /content/drive/MyDrive/data/testing_images/vid_5_31560.jpg: 416x704 1 car, 327.8ms
# image 166/175 /content/drive/MyDrive/data/testing_images/vid_5_31600.jpg: 416x704 2 cars, 304.8ms
# image 167/175 /content/drive/MyDrive/data/testing_images/vid_5_31620.jpg: 416x704 1 car, 221.1ms
# image 168/175 /content/drive/MyDrive/data/testing_images/vid_5_31640.jpg: 416x704 (no detections), 229.5ms
# image 169/175 /content/drive/MyDrive/data/testing_images/vid_5_31660.jpg: 416x704 (no detections), 221.1ms
# image 170/175 /content/drive/MyDrive/data/testing_images/vid_5_31680.jpg: 416x704 (no detections), 234.7ms
# image 171/175 /content/drive/MyDrive/data/testing_images/vid_5_31700.jpg: 416x704 1 car, 233.1ms
# image 172/175 /content/drive/MyDrive/data/testing_images/vid_5_31720.jpg: 416x704 1 car, 240.4ms
# image 173/175 /content/drive/MyDrive/data/testing_images/vid_5_400.jpg: 416x704 1 car, 235.2ms
# image 174/175 /content/drive/MyDrive/data/testing_images/vid_5_420.jpg: 416x704 1 car, 230.1ms
# image 175/175 /content/drive/MyDrive/data/testing_images/vid_5_440.jpg: 416x704 1 car, 227.7ms
# Speed: 0.6ms pre-process, 263.8ms inference, 0.8ms NMS per image at shape (1, 3, 704, 704)
# Results saved to yolov5/runs/detect/exp

# %%
predicted_files = []
for (dirpath, dirnames, filenames) in os.walk("yolov5/runs/detect/exp"):
    predicted_files.extend(filenames)

# %%
len(predicted_files)
# Out:
# 175

# %%
Image(filename=f'yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp/{random.choice(predicted_files)}')
